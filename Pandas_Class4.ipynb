# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Filtering Data

# %%
df=pd.read_csv("nobel.csv")

# %%
df.head()
# Out:
#    year    category                                           prize  \
# 0  1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1  1901  Literature              The Nobel Prize in Literature 1901
# 2  1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3  1901       Peace                      The Nobel Peace Prize 1901
# 4  1901       Peace                      The Nobel Peace Prize 1901
#
#                                           motivation prize_share  laureate_id  \
# 0  "in recognition of the extraordinary services ...         1/1          160
# 1  "in special recognition of his poetic composit...         1/1          569
# 2  "for his work on serum therapy, especially its...         1/1          293
# 3                                                NaN         1/2          462
# 4                                                NaN         1/2          463
#
#   laureate_type                     full_name  birth_date         birth_city  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   year                  1000 non-null   int64
#  1   category              1000 non-null   object
#  2   prize                 1000 non-null   object
#  3   motivation            912 non-null    object
#  4   prize_share           1000 non-null   object
#  5   laureate_id           1000 non-null   int64
#  6   laureate_type         1000 non-null   object
#  7   full_name             1000 non-null   object
#  8   birth_date            968 non-null    object
#  9   birth_city            964 non-null    object
#  10  birth_country         969 non-null    object
#  11  sex                   970 non-null    object
#  12  organization_name     736 non-null    object
#  13  organization_city     735 non-null    object
#  14  organization_country  735 non-null    object
# ...

# %% [markdown]
# ### Null Values

# %%
df.isnull()
# Out:
#       year  category  prize  motivation  prize_share  laureate_id  \
# 0    False     False  False       False        False        False
# 1    False     False  False       False        False        False
# 2    False     False  False       False        False        False
# 3    False     False  False        True        False        False
# 4    False     False  False        True        False        False
# ..     ...       ...    ...         ...          ...          ...
# 995  False     False  False       False        False        False
# 996  False     False  False       False        False        False
# 997  False     False  False       False        False        False
# 998  False     False  False       False        False        False
# 999  False     False  False       False        False        False
#
#      laureate_type  full_name  birth_date  birth_city  birth_country    sex  \
# 0            False      False       False       False          False  False
# ...

# %%
df.isnull().sum()
# Out:
# year                      0
# category                  0
# prize                     0
# motivation               88
# prize_share               0
# laureate_id               0
# laureate_type             0
# full_name                 0
# birth_date               32
# birth_city               36
# birth_country            31
# sex                      30
# organization_name       264
# organization_city       265
# organization_country    265
# death_date              404
# death_city              421
# death_country           415
# dtype: int64

# %%
df.isna().sum() #same as null
# Out:
# year                      0
# category                  0
# prize                     0
# motivation               88
# prize_share               0
# laureate_id               0
# laureate_type             0
# full_name                 0
# birth_date               32
# birth_city               36
# birth_country            31
# sex                      30
# organization_name       264
# organization_city       265
# organization_country    265
# death_date              404
# death_city              421
# death_country           415
# dtype: int64

# %%
df.isna().sum()!=0
# Out:
# year                    False
# category                False
# prize                   False
# motivation               True
# prize_share             False
# laureate_id             False
# laureate_type           False
# full_name               False
# birth_date               True
# birth_city               True
# birth_country            True
# sex                      True
# organization_name        True
# organization_city        True
# organization_country     True
# death_date               True
# death_city               True
# death_country            True
# dtype: bool

# %% [markdown]
# ### Sorting Values

# %%
df.isna().sum().sort_values()
# Out:
# year                      0
# category                  0
# prize                     0
# prize_share               0
# laureate_id               0
# laureate_type             0
# full_name                 0
# sex                      30
# birth_country            31
# birth_date               32
# birth_city               36
# motivation               88
# organization_name       264
# organization_city       265
# organization_country    265
# death_date              404
# death_country           415
# death_city              421
# dtype: int64

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# death_city              421
# death_country           415
# death_date              404
# organization_country    265
# organization_city       265
# organization_name       264
# motivation               88
# birth_city               36
# birth_date               32
# birth_country            31
# sex                      30
# category                  0
# full_name                 0
# laureate_type             0
# laureate_id               0
# prize_share               0
# prize                     0
# year                      0
# dtype: int64

# %% [markdown]
# ### nunique

# %%
df.category.nunique()
# Out:
# 6

# %%
df['year']
# Out:
# 0      1901
# 1      1901
# 2      1901
# 3      1901
# 4      1901
#        ...
# 995    2023
# 996    2023
# 997    2023
# 998    2023
# 999    2023
# Name: year, Length: 1000, dtype: int64

# %%
df[['year','category']]
# Out:
#      year    category
# 0    1901   Chemistry
# 1    1901  Literature
# 2    1901    Medicine
# 3    1901       Peace
# 4    1901       Peace
# ..    ...         ...
# 995  2023   Chemistry
# 996  2023   Chemistry
# 997  2023  Literature
# 998  2023       Peace
# 999  2023   Economics
#
# [1000 rows x 2 columns]

# %%
df.year
# Out:
# 0      1901
# 1      1901
# 2      1901
# 3      1901
# 4      1901
#        ...
# 995    2023
# 996    2023
# 997    2023
# 998    2023
# 999    2023
# Name: year, Length: 1000, dtype: int64

# %% [markdown]
# ## row wise filtering

# %%
df[df['sex']=='Male']
# Out:
#      year    category                                           prize  \
# 0    1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1    1901  Literature              The Nobel Prize in Literature 1901
# 2    1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3    1901       Peace                      The Nobel Peace Prize 1901
# 4    1901       Peace                      The Nobel Peace Prize 1901
# ..    ...         ...                                             ...
# 992  2023     Physics                 The Nobel Prize in Physics 2023
# 994  2023   Chemistry               The Nobel Prize in Chemistry 2023
# 995  2023   Chemistry               The Nobel Prize in Chemistry 2023
# 996  2023   Chemistry               The Nobel Prize in Chemistry 2023
# 997  2023  Literature              The Nobel Prize in Literature 2023
#
#                                             motivation prize_share  \
# ...

# %%
df[df['sex']=='Female'].head()
# Out:
#      year    category                               prize  \
# 19   1903     Physics     The Nobel Prize in Physics 1903
# 29   1905       Peace          The Nobel Peace Prize 1905
# 51   1909  Literature  The Nobel Prize in Literature 1909
# 62   1911   Chemistry   The Nobel Prize in Chemistry 1911
# 128  1926  Literature  The Nobel Prize in Literature 1926
#
#                                             motivation prize_share  \
# 19   "in recognition of the extraordinary services ...         1/4
# 29                                                 NaN         1/1
# 51   "in appreciation of the lofty idealism, vivid ...         1/1
# 62   "in recognition of her services to the advance...         1/1
# 128  "for her idealistically inspired writings whic...         1/1
#
#      laureate_id laureate_type  \
# 19             6    Individual
# 29           468    Individual
# 51           579    Individual
# 62             6    Individual
# 128          597    Individual
#
# ...

# %%
df[df['sex']=='Female'].head(3)
# Out:
#     year    category                               prize  \
# 19  1903     Physics     The Nobel Prize in Physics 1903
# 29  1905       Peace          The Nobel Peace Prize 1905
# 51  1909  Literature  The Nobel Prize in Literature 1909
#
#                                            motivation prize_share  \
# 19  "in recognition of the extraordinary services ...         1/4
# 29                                                NaN         1/1
# 51  "in appreciation of the lofty idealism, vivid ...         1/1
#
#     laureate_id laureate_type  \
# 19            6    Individual
# 29          468    Individual
# 51          579    Individual
#
#                                             full_name  birth_date birth_city  \
# 19                        Marie Curie, née Sklodowska  1867-11-07     Warsaw
# 29  Baroness Bertha Sophie Felicita von Suttner, n...  1843-06-09     Prague
# 51                      Selma Ottilia Lovisa Lagerlöf  1858-11-20   Mårbacka
#
# ...

# %%
df[df['year']<=1950]
# Out:
#      year    category                                           prize  \
# 0    1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1    1901  Literature              The Nobel Prize in Literature 1901
# 2    1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3    1901       Peace                      The Nobel Peace Prize 1901
# 4    1901       Peace                      The Nobel Peace Prize 1901
# ..    ...         ...                                             ...
# 253  1950    Medicine  The Nobel Prize in Physiology or Medicine 1950
# 254  1950    Medicine  The Nobel Prize in Physiology or Medicine 1950
# 255  1950    Medicine  The Nobel Prize in Physiology or Medicine 1950
# 256  1950       Peace                      The Nobel Peace Prize 1950
# 257  1950     Physics                 The Nobel Prize in Physics 1950
#
#                                             motivation prize_share  \
# ...

# %%
df[(df['year']>=1920) & (df['year']<=1950)]
# Out:
#      year    category                                           prize  \
# 97   1920   Chemistry               The Nobel Prize in Chemistry 1920
# 98   1920  Literature              The Nobel Prize in Literature 1920
# 99   1920    Medicine  The Nobel Prize in Physiology or Medicine 1920
# 100  1920       Peace                      The Nobel Peace Prize 1920
# 101  1920     Physics                 The Nobel Prize in Physics 1920
# ..    ...         ...                                             ...
# 253  1950    Medicine  The Nobel Prize in Physiology or Medicine 1950
# 254  1950    Medicine  The Nobel Prize in Physiology or Medicine 1950
# 255  1950    Medicine  The Nobel Prize in Physiology or Medicine 1950
# 256  1950       Peace                      The Nobel Peace Prize 1950
# 257  1950     Physics                 The Nobel Prize in Physics 1950
#
#                                             motivation prize_share  \
# ...

# %%
df[(df['category']=='Chemistry') | (df['category']=='Physics')]
# Out:
#      year   category                              prize  \
# 0    1901  Chemistry  The Nobel Prize in Chemistry 1901
# 5    1901    Physics    The Nobel Prize in Physics 1901
# 6    1902  Chemistry  The Nobel Prize in Chemistry 1902
# 11   1902    Physics    The Nobel Prize in Physics 1902
# 12   1902    Physics    The Nobel Prize in Physics 1902
# ..    ...        ...                                ...
# 992  2023    Physics    The Nobel Prize in Physics 2023
# 993  2023    Physics    The Nobel Prize in Physics 2023
# 994  2023  Chemistry  The Nobel Prize in Chemistry 2023
# 995  2023  Chemistry  The Nobel Prize in Chemistry 2023
# 996  2023  Chemistry  The Nobel Prize in Chemistry 2023
#
#                                             motivation prize_share  \
# 0    "in recognition of the extraordinary services ...         1/1
# 5    "in recognition of the extraordinary services ...         1/1
# 6    "in recognition of the extraordinary services ...         1/1
# ...

# %%
df[(df['category'] == 'Chemistry') | ((df['category'] == 'Physics') & (df['category'] == 'Medicine'))]
# Out:
#      year   category                              prize  \
# 0    1901  Chemistry  The Nobel Prize in Chemistry 1901
# 6    1902  Chemistry  The Nobel Prize in Chemistry 1902
# 13   1903  Chemistry  The Nobel Prize in Chemistry 1903
# 20   1904  Chemistry  The Nobel Prize in Chemistry 1904
# 26   1905  Chemistry  The Nobel Prize in Chemistry 1905
# ..    ...        ...                                ...
# 980  2022  Chemistry  The Nobel Prize in Chemistry 2022
# 981  2022  Chemistry  The Nobel Prize in Chemistry 2022
# 994  2023  Chemistry  The Nobel Prize in Chemistry 2023
# 995  2023  Chemistry  The Nobel Prize in Chemistry 2023
# 996  2023  Chemistry  The Nobel Prize in Chemistry 2023
#
#                                             motivation prize_share  \
# 0    "in recognition of the extraordinary services ...         1/1
# 6    "in recognition of the extraordinary services ...         1/1
# 13   "in recognition of the extraordinary services ...         1/1
# ...

# %%
df[(df['category']=='Medicine') | (df['category']=='Physics')]
# Out:
#      year  category                                           prize  \
# 2    1901  Medicine  The Nobel Prize in Physiology or Medicine 1901
# 5    1901   Physics                 The Nobel Prize in Physics 1901
# 8    1902  Medicine  The Nobel Prize in Physiology or Medicine 1902
# 11   1902   Physics                 The Nobel Prize in Physics 1902
# 12   1902   Physics                 The Nobel Prize in Physics 1902
# ..    ...       ...                                             ...
# 989  2023  Medicine  The Nobel Prize in Physiology or Medicine 2023
# 990  2023  Medicine  The Nobel Prize in Physiology or Medicine 2023
# 991  2023   Physics                 The Nobel Prize in Physics 2023
# 992  2023   Physics                 The Nobel Prize in Physics 2023
# 993  2023   Physics                 The Nobel Prize in Physics 2023
#
#                                             motivation prize_share  \
# 2    "for his work on serum therapy, especially its...         1/1
# ...

# %%
df[(df['category']=='Literature')]
# Out:
#      year    category                               prize  \
# 1    1901  Literature  The Nobel Prize in Literature 1901
# 7    1902  Literature  The Nobel Prize in Literature 1902
# 14   1903  Literature  The Nobel Prize in Literature 1903
# 21   1904  Literature  The Nobel Prize in Literature 1904
# 22   1904  Literature  The Nobel Prize in Literature 1904
# ..    ...         ...                                 ...
# 945  2019  Literature  The Nobel Prize in Literature 2019
# 958  2020  Literature  The Nobel Prize in Literature 2020
# 969  2021  Literature  The Nobel Prize in Literature 2021
# 982  2022  Literature  The Nobel Prize in Literature 2022
# 997  2023  Literature  The Nobel Prize in Literature 2023
#
#                                             motivation prize_share  \
# 1    "in special recognition of his poetic composit...         1/1
# 7    "the greatest living master of the art of hist...         1/1
# ...

# %%
df['full_name']
# Out:
# 0      Jacobus Henricus van 't Hoff
# 1                   Sully Prudhomme
# 2            Emil Adolf von Behring
# 3                 Jean Henry Dunant
# 4                    Frédéric Passy
#                    ...
# 995                      Louis Brus
# 996                 Aleksey Yekimov
# 997                       Jon Fosse
# 998                Narges Mohammadi
# 999                  Claudia Goldin
# Name: full_name, Length: 1000, dtype: object

# %%
df[df['year'].between(1920,1950)]
# Out:
#      year    category                                           prize  \
# 97   1920   Chemistry               The Nobel Prize in Chemistry 1920
# 98   1920  Literature              The Nobel Prize in Literature 1920
# 99   1920    Medicine  The Nobel Prize in Physiology or Medicine 1920
# 100  1920       Peace                      The Nobel Peace Prize 1920
# 101  1920     Physics                 The Nobel Prize in Physics 1920
# ..    ...         ...                                             ...
# 253  1950    Medicine  The Nobel Prize in Physiology or Medicine 1950
# 254  1950    Medicine  The Nobel Prize in Physiology or Medicine 1950
# 255  1950    Medicine  The Nobel Prize in Physiology or Medicine 1950
# 256  1950       Peace                      The Nobel Peace Prize 1950
# 257  1950     Physics                 The Nobel Prize in Physics 1950
#
#                                             motivation prize_share  \
# ...

# %% [markdown]
# #### loc func is used to filter rows with the help of rows indexes

# %%
df.loc[0:5]
# Out:
#    year    category                                           prize  \
# 0  1901   Chemistry               The Nobel Prize in Chemistry 1901
# 1  1901  Literature              The Nobel Prize in Literature 1901
# 2  1901    Medicine  The Nobel Prize in Physiology or Medicine 1901
# 3  1901       Peace                      The Nobel Peace Prize 1901
# 4  1901       Peace                      The Nobel Peace Prize 1901
# 5  1901     Physics                 The Nobel Prize in Physics 1901
#
#                                           motivation prize_share  laureate_id  \
# 0  "in recognition of the extraordinary services ...         1/1          160
# 1  "in special recognition of his poetic composit...         1/1          569
# 2  "for his work on serum therapy, especially its...         1/1          293
# 3                                                NaN         1/2          462
# 4                                                NaN         1/2          463
# ...

# %%
df.loc[20:25,['sex','full_name']]
# Out:
#      sex                                          full_name
# 20  Male                                 Sir William Ramsay
# 21  Male                                   Frédéric Mistral
# 22  Male                        José Echegaray y Eizaguirre
# 23  Male                              Ivan Petrovich Pavlov
# 24   NaN  Institut de droit international (Institute of ...
# 25  Male                Lord Rayleigh (John William Strutt)

# %%
df.loc[78]
# Out:
# year                                                                 1913
# category                                                          Physics
# prize                                     The Nobel Prize in Physics 1913
# motivation              "for his investigations on the properties of m...
# prize_share                                                           1/1
# laureate_id                                                            18
# laureate_type                                                  Individual
# full_name                                          Heike Kamerlingh Onnes
# birth_date                                                     1853-09-21
# birth_city                                                      Groningen
# birth_country                                                 Netherlands
# sex                                                                  Male
# organization_name                                       Leiden University
# ...

# %% [markdown]
# ### integer location filteration

# %%
df.iloc[0,2]
# Out:
# 'The Nobel Prize in Chemistry 1901'

# %%
df.iloc[[0,4],[4,7]]
# Out:
#   prize_share                     full_name
# 0         1/1  Jacobus Henricus van 't Hoff
# 4         1/2                Frédéric Passy

# %%
df.iloc[10:15,1:6]
# Out:
#       category                               prize  \
# 10       Peace          The Nobel Peace Prize 1902
# 11     Physics     The Nobel Prize in Physics 1902
# 12     Physics     The Nobel Prize in Physics 1902
# 13   Chemistry   The Nobel Prize in Chemistry 1903
# 14  Literature  The Nobel Prize in Literature 1903
#
#                                            motivation prize_share  laureate_id
# 10                                                NaN         1/2          465
# 11  "in recognition of the extraordinary service t...         1/2            2
# 12  "in recognition of the extraordinary service t...         1/2            3
# 13  "in recognition of the extraordinary services ...         1/1          162
# 14  "as a tribute to his noble, magnificent and ve...         1/1          572

# %% [markdown]
# ### Value Count

# %%
df.sex.value_counts()
# Out:
# sex
# Male      905
# Female     65
# Name: count, dtype: int64

# %% [markdown]
# ### Unique Values

# %%
df.category.unique()
# Out:
# array(['Chemistry', 'Literature', 'Medicine', 'Peace', 'Physics',
#        'Economics'], dtype=object)

# %%
len(df.category.unique())
# Out:
# 6

# %% [markdown]
# ### tolist()

# %%
df.category.unique().tolist()
# Out:
# ['Chemistry', 'Literature', 'Medicine', 'Peace', 'Physics', 'Economics']

# %% [markdown]
# ### Aggregate Functions

# %%
df.year.sum()
# Out:
# 1973721

# %%
df=pd.read_excel("titanic.xlsx")
# Out:
# F:\Yasir Py\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
df
# Out:
#       pclass  survived                                  name     sex      age  \
# 0          1         1                        Haghish, E. F.    male  30.0000
# 1          1         1         Allen, Miss. Elisabeth Walton  female  29.0000
# 2          1         1        Allison, Master. Hudson Trevor    male   0.9167
# 3          1         0          Allison, Miss. Helen Loraine  female   2.0000
# 4          1         0  Allison, Mr. Hudson Joshua Creighton    male  30.0000
# ...      ...       ...                                   ...     ...      ...
# 1305       3         0                  Zabour, Miss. Hileni  female  14.5000
# 1306       3         0                 Zabour, Miss. Thamine  female      NaN
# 1307       3         0             Zakarian, Mr. Mapriededer    male  26.5000
# 1308       3         0                   Zakarian, Mr. Ortin    male  27.0000
# 1309       3         0                    Zimmerman, Mr. Leo    male  29.0000
#
# ...

# %%
df.survived.sum()
# Out:
# 501

# %% [markdown]
# ### mean

# %%
df['age'].mean()
# Out:
# 29.881248042024833

# %%
df['age'].max()
# Out:
# 80.0

# %%
df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
df['age'].mode()
# Out:
# 0    24.0
# Name: age, dtype: float64

# %%
df['age'].median()
# Out:
# 28.0

# %%
df['age'].std()
# Out:
# 14.406608702570509

# %% [markdown]
# ### Date Column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1310 entries, 0 to 1309
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1310 non-null   int64
#  1   survived   1310 non-null   int64
#  2   name       1310 non-null   object
#  3   sex        1310 non-null   object
#  4   age        1047 non-null   float64
#  5   sibsp      1310 non-null   int64
#  6   parch      1310 non-null   int64
#  7   ticket     1310 non-null   object
#  8   fare       1309 non-null   float64
#  9   cabin      296 non-null    object
#  10  embarked   1308 non-null   object
#  11  boat       487 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  746 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.4+ KB

# %%
titanic=pd.read_excel("titanic.xlsx")
# Out:
# F:\Yasir Py\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %% [markdown]
# ### Deep Copy and Shallow Copy

# %%
import copy

# %%
titanic2=copy.copy(titanic)

# %%
titanic2
# Out:
#       pclass  survived                                  name     sex      age  \
# 0          1         1                        Haghish, E. F.    male  30.0000
# 1          1         1         Allen, Miss. Elisabeth Walton  female  29.0000
# 2          1         1        Allison, Master. Hudson Trevor    male   0.9167
# 3          1         0          Allison, Miss. Helen Loraine  female   2.0000
# 4          1         0  Allison, Mr. Hudson Joshua Creighton    male  30.0000
# ...      ...       ...                                   ...     ...      ...
# 1305       3         0                  Zabour, Miss. Hileni  female  14.5000
# 1306       3         0                 Zabour, Miss. Thamine  female      NaN
# 1307       3         0             Zakarian, Mr. Mapriededer    male  26.5000
# 1308       3         0                   Zakarian, Mr. Ortin    male  27.0000
# 1309       3         0                    Zimmerman, Mr. Leo    male  29.0000
#
# ...

# %%
titanic2=copy.deepcopy(titanic)

# %%
titanic2
# Out:
#       pclass  survived                                  name     sex      age  \
# 0          1         1                        Haghish, E. F.    male  30.0000
# 1          1         1         Allen, Miss. Elisabeth Walton  female  29.0000
# 2          1         1        Allison, Master. Hudson Trevor    male   0.9167
# 3          1         0          Allison, Miss. Helen Loraine  female   2.0000
# 4          1         0  Allison, Mr. Hudson Joshua Creighton    male  30.0000
# ...      ...       ...                                   ...     ...      ...
# 1305       3         0                  Zabour, Miss. Hileni  female  14.5000
# 1306       3         0                 Zabour, Miss. Thamine  female      NaN
# 1307       3         0             Zakarian, Mr. Mapriededer    male  26.5000
# 1308       3         0                   Zakarian, Mr. Ortin    male  27.0000
# 1309       3         0                    Zimmerman, Mr. Leo    male  29.0000
#
# ...

# %% [markdown]
# ### Handling null Values
# changing in deep copy so that our original data dont get disturbed
